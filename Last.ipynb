# %%
import ccxt
import numpy as np
import pandas as pd
import time
from datetime import datetime
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, concatenate, Dropout, Bidirectional, multiply
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ReduceLROnPlateau

# Конфигурация модели
TIMEFRAMES = ['1m', '5m', '15m', '1h', '4h', '1d', '1w']
LOOKBACK_PERIODS = {
    '1m': 60,
    '5m': 12,
    '15m': 4,
    '1h': 24,
    '4h': 168,
    '1d': 30,
    '1w': 12
}
FEATURES = ['open', 'high', 'low', 'close', 'volume']
NUM_FEATURES = len(FEATURES)

def fetch_multitimeframe_data(symbol='BTC/USDT', exchange_name='binance'):
    exchange = getattr(ccxt, exchange_name)({
        'enableRateLimit': True,
        'options': {'defaultType': 'spot'}
    })

    exchange.load_markets()
    data = {}

    for tf in TIMEFRAMES:
        try:
            print(f"Загрузка {tf} данных...")
            ohlcv = exchange.fetch_ohlcv(symbol, tf, limit=1000)
            df = pd.DataFrame(ohlcv, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])
            df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')
            df.set_index('timestamp', inplace=True)
            data[tf] = df.dropna()
            time.sleep(exchange.rateLimit / 1000)
        except Exception as e:
            print(f"Ошибка при загрузке {tf}: {str(e)}")
            continue

    return data

def align_datasets(raw_data):
    min_samples = min([len(raw_data[tf]) - LOOKBACK_PERIODS[tf] for tf in TIMEFRAMES if tf in raw_data]) - 1

    aligned_data = {}
    scalers = {}

    for tf in TIMEFRAMES:
        if tf not in raw_data or len(raw_data[tf]) < LOOKBACK_PERIODS[tf] + min_samples:
            continue

        scaler = StandardScaler()
        scaled_data = scaler.fit_transform(raw_data[tf][FEATURES])
        scalers[tf] = scaler

        X = []
        start_idx = len(scaled_data) - min_samples - LOOKBACK_PERIODS[tf]
        for i in range(start_idx, len(scaled_data) - LOOKBACK_PERIODS[tf]):
            X.append(scaled_data[i:i+LOOKBACK_PERIODS[tf]])

        aligned_data[tf] = np.array(X)

    return aligned_data, scalers, min_samples

def prepare_training_data(datasets, min_samples):
    X_train = {tf: data[:min_samples-1] for tf, data in datasets.items()}

    y_price = datasets['1m'][1:min_samples, -1, 3]
    y_signal = (datasets['1m'][1:min_samples, -1, 3] > datasets['1m'][:min_samples-1, -1, 3]).astype(int)

    return X_train, {'price_prediction': y_price, 'signal': y_signal}

def create_model(input_shapes):
    inputs = []
    branches = []

    for tf, shape in input_shapes.items():
        inp = Input(shape=shape, name=f'input_{tf}')
        x = Bidirectional(LSTM(128, return_sequences=True, kernel_regularizer=l2(0.01)))(inp)
        x = Dropout(0.4)(x)
        x = LSTM(64, kernel_regularizer=l2(0.01))(x)
        branches.append(x)
        inputs.append(inp)

    merged = concatenate(branches)

    attention = Dense(len(branches)*64, activation='softmax')(merged)
    attended = multiply([merged, attention])

    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(attended)
    x = Dropout(0.5)(x)

    reg_output = Dense(1, name='price_prediction')(x)
    class_output = Dense(1, activation='sigmoid', name='signal')(x)

    model = Model(inputs=inputs, outputs=[reg_output, class_output])
    model.compile(
        optimizer=Adam(0.0005),
        loss={'price_prediction': 'mse', 'signal': 'binary_crossentropy'},
        metrics={'price_prediction': ['mae'], 'signal': ['accuracy']}
    )
    return model

def generate_signal(current_price, predicted_price, threshold=0.001):
    price_change = (predicted_price - current_price) / current_price
    if price_change > threshold:
        return 'buy'
    elif price_change < -threshold:
        return 'sell'
    else:
        return 'hold'

if __name__ == "__main__":
    raw_data = fetch_multitimeframe_data()
    datasets, scalers, min_samples = align_datasets(raw_data)

    if not datasets:
        raise ValueError("Недостаточно данных для обучения")

    print(f"Используется {min_samples-1} образцов для обучения")

    X_train, y_train = prepare_training_data(datasets, min_samples)

    input_shapes = {tf: (LOOKBACK_PERIODS[tf], NUM_FEATURES) for tf in datasets}
    model = create_model(input_shapes)

    X_train_named = {f'input_{tf}': data for tf, data in X_train.items()}

    lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6, verbose=1)

    history = model.fit(
        X_train_named,
        y_train,
        epochs=50,
        batch_size=64,
        validation_split=0.2,
        verbose=1,
        callbacks=[lr_scheduler]
    )

    print("Прогнозирование...")

    current_data = {}
    for tf in datasets:
        last_seq = datasets[tf][-1]
        current_data[f'input_{tf}'] = np.expand_dims(last_seq, axis=0)

    price_pred_scaled, signal_prob = model.predict(current_data)

    # Инвертирование стандартизации для прогнозируемой цены
    scaler_1m = scalers['1m']
    dummy = np.zeros((1, NUM_FEATURES))
    dummy[0, 3] = price_pred_scaled[0][0]
    price_pred_unscaled = scaler_1m.inverse_transform(dummy)[0, 3]

    signal = generate_signal(
        current_price=raw_data['1m'].iloc[-1]['close'],
        predicted_price=price_pred_unscaled,
        threshold=0.002
    )

    print("\nРезультаты:")
    print(f"Текущая цена: {raw_data['1m'].iloc[-1]['close']}")
    print(f"Прогнозируемая цена: {price_pred_unscaled}")
    print(f"Вероятность роста: {signal_prob[0][0]:.4f}")
    print(f"Рекомендуемое действие: {signal.upper()}")

    print("\nМетрики валидации (последняя эпоха):")
    print(f"Val MAE: {history.history['val_price_prediction_mae'][-1]:.4f}")
    print(f"Val Accuracy: {history.history['val_signal_accuracy'][-1]:.4f}")
    print(f"Val Price Loss: {history.history['val_price_prediction_loss'][-1]:.4f}")
    print(f"Val Signal Loss: {history.history['val_signal_loss'][-1]:.4f}")
# Out:
# Загрузка 1m данных...
# Загрузка 5m данных...
# Загрузка 15m данных...
# Загрузка 1h данных...
# Загрузка 4h данных...
# Загрузка 1d данных...
# Загрузка 1w данных...
# Используется 393 образцов для обучения
# Epoch 1/50
# 5/5 [==============================] - 52s 4s/step - loss: 24.4998 - price_prediction_loss: 1.8455 - signal_loss: 0.6931 - price_prediction_mae: 1.2294 - signal_accuracy: 0.5191 - val_loss: 23.6686 - val_price_prediction_loss: 1.9568 - val_signal_loss: 0.6933 - val_price_prediction_mae: 1.3858 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 2/50
# 5/5 [==============================] - 12s 2s/step - loss: 22.9278 - price_prediction_loss: 1.8045 - signal_loss: 0.6929 - price_prediction_mae: 1.2192 - signal_accuracy: 0.5510 - val_loss: 22.1105 - val_price_prediction_loss: 1.8808 - val_signal_loss: 0.6934 - val_price_prediction_mae: 1.3581 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 3/50
# 5/5 [==============================] - 11s 2s/step - loss: 21.4330 - price_prediction_loss: 1.7596 - signal_loss: 0.6931 - price_prediction_mae: 1.2077 - signal_accuracy: 0.5000 - val_loss: 20.6289 - val_price_prediction_loss: 1.7991 - val_signal_loss: 0.6936 - val_price_prediction_mae: 1.3276 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 4/50
# 5/5 [==============================] - 12s 2s/step - loss: 20.0194 - price_prediction_loss: 1.7135 - signal_loss: 0.6930 - price_prediction_mae: 1.1957 - signal_accuracy: 0.5287 - val_loss: 19.2206 - val_price_prediction_loss: 1.7075 - val_signal_loss: 0.6938 - val_price_prediction_mae: 1.2927 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 5/50
# 5/5 [==============================] - 12s 2s/step - loss: 18.6811 - price_prediction_loss: 1.6592 - signal_loss: 0.6936 - price_prediction_mae: 1.1813 - signal_accuracy: 0.4968 - val_loss: 17.8780 - val_price_prediction_loss: 1.5993 - val_signal_loss: 0.6941 - val_price_prediction_mae: 1.2502 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 6/50
# 5/5 [==============================] - 12s 2s/step - loss: 17.4084 - price_prediction_loss: 1.5896 - signal_loss: 0.6931 - price_prediction_mae: 1.1604 - signal_accuracy: 0.4777 - val_loss: 16.5901 - val_price_prediction_loss: 1.4646 - val_signal_loss: 0.6945 - val_price_prediction_mae: 1.1951 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 7/50
# 5/5 [==============================] - 11s 2s/step - loss: 16.1970 - price_prediction_loss: 1.5005 - signal_loss: 0.6933 - price_prediction_mae: 1.1306 - signal_accuracy: 0.5191 - val_loss: 15.3512 - val_price_prediction_loss: 1.2999 - val_signal_loss: 0.6951 - val_price_prediction_mae: 1.1241 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 8/50
# 5/5 [==============================] - 11s 2s/step - loss: 15.0391 - price_prediction_loss: 1.3886 - signal_loss: 0.6926 - price_prediction_mae: 1.0901 - signal_accuracy: 0.5000 - val_loss: 14.1675 - val_price_prediction_loss: 1.1156 - val_signal_loss: 0.6959 - val_price_prediction_mae: 1.0390 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 9/50
# 5/5 [==============================] - 11s 2s/step - loss: 13.9448 - price_prediction_loss: 1.2654 - signal_loss: 0.6937 - price_prediction_mae: 1.0392 - signal_accuracy: 0.4904 - val_loss: 13.0434 - val_price_prediction_loss: 0.9204 - val_signal_loss: 0.6967 - val_price_prediction_mae: 0.9404 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 10/50
# 5/5 [==============================] - 12s 2s/step - loss: 12.8957 - price_prediction_loss: 1.1183 - signal_loss: 0.6955 - price_prediction_mae: 0.9774 - signal_accuracy: 0.5096 - val_loss: 11.9881 - val_price_prediction_loss: 0.7285 - val_signal_loss: 0.6980 - val_price_prediction_mae: 0.8321 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 11/50
# 5/5 [==============================] - 12s 2s/step - loss: 11.9112 - price_prediction_loss: 0.9785 - signal_loss: 0.6913 - price_prediction_mae: 0.9099 - signal_accuracy: 0.5223 - val_loss: 11.0112 - val_price_prediction_loss: 0.5551 - val_signal_loss: 0.6987 - val_price_prediction_mae: 0.7205 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 12/50
# 5/5 [==============================] - 12s 2s/step - loss: 10.9684 - price_prediction_loss: 0.8155 - signal_loss: 0.6935 - price_prediction_mae: 0.8229 - signal_accuracy: 0.4968 - val_loss: 10.1145 - val_price_prediction_loss: 0.4056 - val_signal_loss: 0.6996 - val_price_prediction_mae: 0.6081 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 13/50
# 5/5 [==============================] - 12s 2s/step - loss: 10.0956 - price_prediction_loss: 0.6704 - signal_loss: 0.6928 - price_prediction_mae: 0.7374 - signal_accuracy: 0.5000 - val_loss: 9.2969 - val_price_prediction_loss: 0.2831 - val_signal_loss: 0.7003 - val_price_prediction_mae: 0.4972 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 14/50
# 5/5 [==============================] - 12s 2s/step - loss: 9.3162 - price_prediction_loss: 0.5628 - signal_loss: 0.6976 - price_prediction_mae: 0.6723 - signal_accuracy: 0.4777 - val_loss: 8.5507 - val_price_prediction_loss: 0.1836 - val_signal_loss: 0.7009 - val_price_prediction_mae: 0.3846 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 15/50
# 5/5 [==============================] - 12s 2s/step - loss: 8.5703 - price_prediction_loss: 0.4494 - signal_loss: 0.6942 - price_prediction_mae: 0.5935 - signal_accuracy: 0.5318 - val_loss: 7.8756 - val_price_prediction_loss: 0.1095 - val_signal_loss: 0.7011 - val_price_prediction_mae: 0.2840 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 16/50
# 5/5 [==============================] - 13s 2s/step - loss: 7.9207 - price_prediction_loss: 0.3847 - signal_loss: 0.6933 - price_prediction_mae: 0.5517 - signal_accuracy: 0.5064 - val_loss: 7.2701 - val_price_prediction_loss: 0.0620 - val_signal_loss: 0.7011 - val_price_prediction_mae: 0.2076 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 17/50
# 5/5 [==============================] - 12s 2s/step - loss: 7.2934 - price_prediction_loss: 0.3012 - signal_loss: 0.6915 - price_prediction_mae: 0.4796 - signal_accuracy: 0.5159 - val_loss: 6.7292 - val_price_prediction_loss: 0.0391 - val_signal_loss: 0.7009 - val_price_prediction_mae: 0.1681 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 18/50
# 5/5 [==============================] - 12s 2s/step - loss: 6.7301 - price_prediction_loss: 0.2396 - signal_loss: 0.6926 - price_prediction_mae: 0.4228 - signal_accuracy: 0.5414 - val_loss: 6.2475 - val_price_prediction_loss: 0.0378 - val_signal_loss: 0.7005 - val_price_prediction_mae: 0.1565 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 19/50
# 5/5 [==============================] - 12s 2s/step - loss: 6.2164 - price_prediction_loss: 0.1891 - signal_loss: 0.6952 - price_prediction_mae: 0.3722 - signal_accuracy: 0.5191 - val_loss: 5.8185 - val_price_prediction_loss: 0.0540 - val_signal_loss: 0.6998 - val_price_prediction_mae: 0.1828 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 20/50
# 5/5 [==============================] - 12s 2s/step - loss: 5.7512 - price_prediction_loss: 0.1542 - signal_loss: 0.6963 - price_prediction_mae: 0.3359 - signal_accuracy: 0.5032 - val_loss: 5.4327 - val_price_prediction_loss: 0.0804 - val_signal_loss: 0.6991 - val_price_prediction_mae: 0.2343 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 21/50
# 5/5 [==============================] - 11s 2s/step - loss: 5.3198 - price_prediction_loss: 0.1265 - signal_loss: 0.6918 - price_prediction_mae: 0.3008 - signal_accuracy: 0.5127 - val_loss: 5.0798 - val_price_prediction_loss: 0.1086 - val_signal_loss: 0.6985 - val_price_prediction_mae: 0.2790 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 22/50
# 5/5 [==============================] - 12s 2s/step - loss: 4.9260 - price_prediction_loss: 0.1023 - signal_loss: 0.6914 - price_prediction_mae: 0.2595 - signal_accuracy: 0.5318 - val_loss: 4.7528 - val_price_prediction_loss: 0.1343 - val_signal_loss: 0.6977 - val_price_prediction_mae: 0.3122 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 23/50
# 5/5 [==============================] - 12s 2s/step - loss: 4.5670 - price_prediction_loss: 0.0822 - signal_loss: 0.6936 - price_prediction_mae: 0.2289 - signal_accuracy: 0.5096 - val_loss: 4.4454 - val_price_prediction_loss: 0.1527 - val_signal_loss: 0.6971 - val_price_prediction_mae: 0.3385 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 24/50
# 5/5 [==============================] - 12s 2s/step - loss: 4.2440 - price_prediction_loss: 0.0698 - signal_loss: 0.6984 - price_prediction_mae: 0.2170 - signal_accuracy: 0.4459 - val_loss: 4.1657 - val_price_prediction_loss: 0.1738 - val_signal_loss: 0.6965 - val_price_prediction_mae: 0.3650 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 25/50
# 5/5 [==============================] - 12s 2s/step - loss: 3.9497 - price_prediction_loss: 0.0725 - signal_loss: 0.6924 - price_prediction_mae: 0.2185 - signal_accuracy: 0.5191 - val_loss: 3.9036 - val_price_prediction_loss: 0.1900 - val_signal_loss: 0.6955 - val_price_prediction_mae: 0.3833 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 26/50
# 5/5 [==============================] - 12s 2s/step - loss: 3.6680 - price_prediction_loss: 0.0619 - signal_loss: 0.6901 - price_prediction_mae: 0.1997 - signal_accuracy: 0.5605 - val_loss: 3.6676 - val_price_prediction_loss: 0.2107 - val_signal_loss: 0.6947 - val_price_prediction_mae: 0.4075 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 27/50
# 5/5 [==============================] - 13s 3s/step - loss: 3.4180 - price_prediction_loss: 0.0552 - signal_loss: 0.6945 - price_prediction_mae: 0.1897 - signal_accuracy: 0.5318 - val_loss: 3.4381 - val_price_prediction_loss: 0.2175 - val_signal_loss: 0.6940 - val_price_prediction_mae: 0.4151 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 28/50
# 5/5 [==============================] - 13s 3s/step - loss: 3.1978 - price_prediction_loss: 0.0614 - signal_loss: 0.6962 - price_prediction_mae: 0.2017 - signal_accuracy: 0.4809 - val_loss: 3.2073 - val_price_prediction_loss: 0.2041 - val_signal_loss: 0.6934 - val_price_prediction_mae: 0.3942 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 29/50
# 5/5 [==============================] - 14s 3s/step - loss: 2.9851 - price_prediction_loss: 0.0594 - signal_loss: 0.6955 - price_prediction_mae: 0.1923 - signal_accuracy: 0.4841 - val_loss: 3.0280 - val_price_prediction_loss: 0.2249 - val_signal_loss: 0.6929 - val_price_prediction_mae: 0.4228 - val_signal_accuracy: 0.4430 - lr: 5.0000e-04
# Epoch 30/50
# 5/5 [==============================] - 15s 3s/step - loss: 2.7808 - price_prediction_loss: 0.0517 - signal_loss: 0.6922 - price_prediction_mae: 0.1794 - signal_accuracy: 0.5223 - val_loss: 2.8578 - val_price_prediction_loss: 0.2391 - val_signal_loss: 0.6922 - val_price_prediction_mae: 0.4416 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 31/50
# 5/5 [==============================] - 13s 3s/step - loss: 2.5981 - price_prediction_loss: 0.0478 - signal_loss: 0.6911 - price_prediction_mae: 0.1745 - signal_accuracy: 0.5541 - val_loss: 2.6729 - val_price_prediction_loss: 0.2233 - val_signal_loss: 0.6917 - val_price_prediction_mae: 0.4219 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 32/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.4344 - price_prediction_loss: 0.0434 - signal_loss: 0.6949 - price_prediction_mae: 0.1715 - signal_accuracy: 0.5223 - val_loss: 2.5283 - val_price_prediction_loss: 0.2333 - val_signal_loss: 0.6917 - val_price_prediction_mae: 0.4381 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 33/50
# 5/5 [==============================] - 14s 3s/step - loss: 2.2831 - price_prediction_loss: 0.0425 - signal_loss: 0.6938 - price_prediction_mae: 0.1655 - signal_accuracy: 0.5032 - val_loss: 2.3910 - val_price_prediction_loss: 0.2380 - val_signal_loss: 0.6917 - val_price_prediction_mae: 0.4466 - val_signal_accuracy: 0.5570 - lr: 5.0000e-04
# Epoch 34/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.1411 - price_prediction_loss: 0.0447 - signal_loss: 0.6870 - price_prediction_mae: 0.1683 - signal_accuracy: 0.5828 - val_loss: 2.2592 - val_price_prediction_loss: 0.2367 - val_signal_loss: 0.6913 - val_price_prediction_mae: 0.4394 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 35/50
# 5/5 [==============================] - 12s 2s/step - loss: 2.0205 - price_prediction_loss: 0.0481 - signal_loss: 0.6888 - price_prediction_mae: 0.1784 - signal_accuracy: 0.5382 - val_loss: 2.1318 - val_price_prediction_loss: 0.2285 - val_signal_loss: 0.6914 - val_price_prediction_mae: 0.4309 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 36/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.9058 - price_prediction_loss: 0.0425 - signal_loss: 0.6950 - price_prediction_mae: 0.1647 - signal_accuracy: 0.4777 - val_loss: 2.0205 - val_price_prediction_loss: 0.2265 - val_signal_loss: 0.6913 - val_price_prediction_mae: 0.4315 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 37/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.8571 - price_prediction_loss: 0.0965 - signal_loss: 0.6974 - price_prediction_mae: 0.2198 - signal_accuracy: 0.4936 - val_loss: 1.9007 - val_price_prediction_loss: 0.2054 - val_signal_loss: 0.6907 - val_price_prediction_mae: 0.4015 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 38/50
# 5/5 [==============================] - 12s 3s/step - loss: 1.7218 - price_prediction_loss: 0.0622 - signal_loss: 0.6903 - price_prediction_mae: 0.2006 - signal_accuracy: 0.5414 - val_loss: 1.8124 - val_price_prediction_loss: 0.2058 - val_signal_loss: 0.6903 - val_price_prediction_mae: 0.4069 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 39/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.6414 - price_prediction_loss: 0.0657 - signal_loss: 0.6916 - price_prediction_mae: 0.2044 - signal_accuracy: 0.5637 - val_loss: 1.7676 - val_price_prediction_loss: 0.2415 - val_signal_loss: 0.6908 - val_price_prediction_mae: 0.4521 - val_signal_accuracy: 0.5570 - lr: 5.0000e-04
# Epoch 40/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.5590 - price_prediction_loss: 0.0602 - signal_loss: 0.6934 - price_prediction_mae: 0.1978 - signal_accuracy: 0.5287 - val_loss: 1.6901 - val_price_prediction_loss: 0.2395 - val_signal_loss: 0.6902 - val_price_prediction_mae: 0.4436 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 41/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.4714 - price_prediction_loss: 0.0496 - signal_loss: 0.6887 - price_prediction_mae: 0.1801 - signal_accuracy: 0.5478 - val_loss: 1.6132 - val_price_prediction_loss: 0.2312 - val_signal_loss: 0.6902 - val_price_prediction_mae: 0.4311 - val_signal_accuracy: 0.5696 - lr: 5.0000e-04
# Epoch 42/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.4052 - price_prediction_loss: 0.0464 - signal_loss: 0.6922 - price_prediction_mae: 0.1738 - signal_accuracy: 0.5127 - val_loss: 1.5494 - val_price_prediction_loss: 0.2306 - val_signal_loss: 0.6900 - val_price_prediction_mae: 0.4314 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 43/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.3442 - price_prediction_loss: 0.0453 - signal_loss: 0.6930 - price_prediction_mae: 0.1691 - signal_accuracy: 0.5127 - val_loss: 1.4984 - val_price_prediction_loss: 0.2370 - val_signal_loss: 0.6899 - val_price_prediction_mae: 0.4400 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 44/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.2855 - price_prediction_loss: 0.0471 - signal_loss: 0.6878 - price_prediction_mae: 0.1750 - signal_accuracy: 0.5096 - val_loss: 1.4640 - val_price_prediction_loss: 0.2543 - val_signal_loss: 0.6904 - val_price_prediction_mae: 0.4654 - val_signal_accuracy: 0.5696 - lr: 5.0000e-04
# Epoch 45/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.2426 - price_prediction_loss: 0.0494 - signal_loss: 0.6929 - price_prediction_mae: 0.1791 - signal_accuracy: 0.5127 - val_loss: 1.4167 - val_price_prediction_loss: 0.2549 - val_signal_loss: 0.6901 - val_price_prediction_mae: 0.4660 - val_signal_accuracy: 0.5696 - lr: 5.0000e-04
# Epoch 46/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.1905 - price_prediction_loss: 0.0427 - signal_loss: 0.6934 - price_prediction_mae: 0.1673 - signal_accuracy: 0.5191 - val_loss: 1.3550 - val_price_prediction_loss: 0.2372 - val_signal_loss: 0.6895 - val_price_prediction_mae: 0.4426 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 47/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.1522 - price_prediction_loss: 0.0451 - signal_loss: 0.6946 - price_prediction_mae: 0.1628 - signal_accuracy: 0.5350 - val_loss: 1.3087 - val_price_prediction_loss: 0.2304 - val_signal_loss: 0.6894 - val_price_prediction_mae: 0.4326 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 48/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.1121 - price_prediction_loss: 0.0463 - signal_loss: 0.6912 - price_prediction_mae: 0.1743 - signal_accuracy: 0.5382 - val_loss: 1.2876 - val_price_prediction_loss: 0.2447 - val_signal_loss: 0.6897 - val_price_prediction_mae: 0.4531 - val_signal_accuracy: 0.5823 - lr: 5.0000e-04
# Epoch 49/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0742 - price_prediction_loss: 0.0430 - signal_loss: 0.6910 - price_prediction_mae: 0.1661 - signal_accuracy: 0.5318 - val_loss: 1.2606 - val_price_prediction_loss: 0.2513 - val_signal_loss: 0.6884 - val_price_prediction_mae: 0.4575 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Epoch 50/50
# 5/5 [==============================] - 12s 2s/step - loss: 1.0470 - price_prediction_loss: 0.0466 - signal_loss: 0.6912 - price_prediction_mae: 0.1702 - signal_accuracy: 0.5414 - val_loss: 1.2216 - val_price_prediction_loss: 0.2418 - val_signal_loss: 0.6883 - val_price_prediction_mae: 0.4476 - val_signal_accuracy: 0.5949 - lr: 5.0000e-04
# Прогнозирование...
# 1/1 [==============================] - 6s 6s/step
#
# Результаты:
# Текущая цена: 107579.85
# Прогнозируемая цена: 107317.04655318541
# Вероятность роста: 0.5140
# Рекомендуемое действие: SELL
#
# Метрики валидации (последняя эпоха):
# Val MAE: 0.4476
# Val Accuracy: 0.5949
# Val Price Loss: 0.2418
# Val Signal Loss: 0.6883
